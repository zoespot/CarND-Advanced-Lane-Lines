# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
# # Project: Advanced Lane Finding
# challenge: put dstpts closer to picture edges

# %%
# Imports library
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import glob
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML
import os

# %% [markdown]
# ## Camera Calibration

# %%
#get camera calibaration mtx, dist
objpoints = [] #3D points in real world 
imgpoints =[] #2D points in image plane
#prepare object points like (0,0,0),(1,0,0)...(8,5,0) 9x6
nx = 9 # the number of inside corners in x
ny = 6 # the number of inside corners in y
objp =np.zeros((ny*nx,3),np.float32)
objp[:,:2] = np.mgrid[0:nx,0:ny].T.reshape(-1,2) # x,y coordinates

for name in glob.glob('camera_cal/*'):
    img = cv2.imread(name)
    #convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    #Find chessboard corners
    ret, corners = cv2.findChessboardCorners(gray, (nx,ny), None)
    #If corneres  found 
    if ret == True:
        imgpoints.append(corners)
        objpoints.append(objp)

#calibrate camera 
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)

# %%
#example: undistort chessboard image with calibration matrix
img = cv2.imread('camera_cal\calibration1.jpg')
dst = cv2.undistort(img, mtx, dist, None, mtx)
plt.figure(figsize=(10,5))
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.subplot(122),plt.imshow(dst),plt.title('Undistorted')
plt.show()

# %% [markdown]
# ## Thresholding
# Use combinations of color and gradient thresholds to generate a binary image where the lane lines are clearly visible.

# %%
def binary_threshold(img,mtx,dist):
    # undistort image with camera calibration matrix
    undistorted = cv2.undistort(img, mtx, dist, None, mtx)

    # Convert to HLS color space and separate the S channel
    hls = cv2.cvtColor(undistorted, cv2.COLOR_RGB2HLS)
    s_channel = hls[:,:,2]

    # Grayscale image
    gray = cv2.cvtColor(undistorted, cv2.COLOR_RGB2GRAY)

   # Sobel x
    sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0) # Take the derivative in x
    abs_sobelx = np.absolute(sobelx) # Absolute x derivative to accentuate lines away from horizontal
    scaled_sobelx = np.uint8(255*abs_sobelx/np.max(abs_sobelx))

    # Threshold x gradient 20-100
    thresh_min = 20
    thresh_max = 100
    sxbinary = np.zeros_like(scaled_sobelx)
    sxbinary[(scaled_sobelx >= thresh_min) & (scaled_sobelx <= thresh_max)] = 1
    
    # Sobel y
    sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1) # Take the derivative in x
    abs_sobely = np.absolute(sobely) # Absolute x derivative to accentuate lines away from horizontal
    scaled_sobely = np.uint8(255*abs_sobelx/np.max(abs_sobelx))

    # Threshold y gradient 20-100
    thresh_min = 10
    thresh_max = 100
    sybinary = np.zeros_like(scaled_sobely)
    sybinary[(scaled_sobely >= thresh_min) & (scaled_sobely <= thresh_max)] = 1   
    
    # Threshold color channel 170-255, 150-210
    s_thresh_min = 150
    s_thresh_max = 210
    s_binary = np.zeros_like(s_channel)
    s_binary[(s_channel >= s_thresh_min) & (s_channel <= s_thresh_max)] = 1

    # Stack each channel to view their individual contributions in green and blue respectively
    # This returns a stack of the two binary images, whose components you can see as different colors
    color_binary = np.dstack((np.zeros_like(sxbinary), sxbinary, s_binary)) * 255

    # Combine the two binary thresholds
    combined_binary = np.zeros_like(sxbinary)
    combined_binary[(s_binary == 1) | (sxbinary == 1)] = 1
    
    # Option to add sobel on y axis 
    
#     color_binary = np.dstack((sybinary, sxbinary, s_binary)) * 255
#     combined_binary = np.zeros_like(sxbinary)
    #combined_binary[(s_binary == 1) | ((sybinary == 1) & (sxbinary == 1))] = 1

    
    return color_binary, combined_binary

# Plotting thresholded images
img = cv2.imread('issue_images/OrigFrame015.jpg')
# img = cv2.imread('issue_images/OrigFrame025.jpg')
# img = cv2.imread('issue_images/issue26.jpg')
# img = cv2.imread('test_images/straight_lines2.jpg')
color_binary, combined_binary = binary_threshold(img, mtx, dist)
plt.figure(figsize=(16,8))
plt.subplot(131),plt.imshow(img),plt.title('Original')
plt.subplot(132),plt.imshow(color_binary),plt.title('Stacked thresholds')
plt.subplot(133),plt.imshow(combined_binary, cmap='gray'),plt.title('Combined S channel and gradient thresholds')
plt.show()

# %% [markdown]
# ## Perspective Transform

# %%
# manually choose the souce points on the original image
pt1=(313,650)
pt2=(1000,650)
# pt1=(215,720)
# pt2=(1110,720)
# pt3=(689,450)
# pt4=(595,450)
# pt3=(770,500)
# # pt4=(525,500)
pt3=(720,470)
pt4=(570,470)
src_pts = np.array([[pt1,pt2,pt3,pt4]], dtype=np.float32)
    
# manually choose the desstination points on the unwarped image
offset_top =720-650
offset_bot = pt3[1]/4
offset_left = 0
offset_right = offset_left
dpt1=(pt1[0]-offset_left,img.shape[0]-offset_top)
dpt2=(pt2[0]+offset_right,img.shape[0]-offset_top)
dpt3=(pt2[0]+offset_right,offset_bot)
dpt4=(pt1[0]-offset_left,offset_bot)
dst_pts = np.array([[dpt1,dpt2,dpt3,dpt4]], dtype=np.float32)
Xpixel= dpt2[0]-dpt1[0]
Ypixel= 700-420
# print(Xpixel,Ypixel)
# Function for perspective transform
def perspective_transform(img,src_pts,dst_pts):  

    M = cv2.getPerspectiveTransform(src_pts,dst_pts)
    Minv = cv2.getPerspectiveTransform(dst_pts,src_pts)
    img_size= (img.shape[1],img.shape[0])
    warped =cv2.warpPerspective(img, M, img_size, flags=cv2.INTER_LINEAR)
    
    return warped, M, Minv

# %%
# perspective transform applied on combined_binary image from thresholding step
img = cv2.imread('test_images/straight_lines2.jpg')
color_binary, combined_binary = binary_threshold(img, mtx, dist)
binary_warped, M, Minv = perspective_transform(combined_binary,src_pts,dst_pts)

plt.figure(figsize=(16,8))
plt.subplot(121),plt.imshow(combined_binary, cmap ='gray'),plt.title('Combined_binary image with src. points drawn'),\
    plt.plot([pt1[0],pt2[0],pt3[0],pt4[0],pt1[0]],[pt1[1],pt2[1],pt3[1],pt4[1],pt1[1]],linewidth=4)
    
plt.subplot(122),plt.imshow(binary_warped, cmap ='gray'),plt.title('Warped image with dest. points drawn'),\
    plt.plot([dpt1[0],dpt2[0],dpt3[0],dpt4[0],dpt1[0]],[dpt1[1],dpt2[1],dpt3[1],dpt4[1],dpt1[1]],linewidth=4)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1f47c1a9e48>,
#  <matplotlib.image.AxesImage at 0x1f400157358>,
#  <matplotlib.text.Text at 0x1f40017c198>,
#  [<matplotlib.lines.Line2D at 0x1f400162c50>])

# %%
# perspective transform applied on image with curved lines
# img = cv2.imread('test_images/test3.jpg')
img = cv2.imread('issue_images/OrigFrame015.jpg')
# img = cv2.imread('issue_images/OrigFrame025.jpg')
# img = cv2.imread('issue_images/OrigFrame014.jpg')
# img = cv2.imread('issue_images/issue26.jpg')
color_binary, combined_binary = binary_threshold(img, mtx, dist)
binary_warped, M , Minv = perspective_transform(combined_binary,src_pts,dst_pts)

plt.figure(figsize=(16,8))
plt.subplot(121),plt.imshow(combined_binary, cmap ='gray'),plt.title('Combined_binary image with src. points drawn')  
plt.subplot(122),plt.imshow(binary_warped, cmap ='gray'),plt.title('Warped image with dest. points drawn')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1f47c1ccb38>,
#  <matplotlib.image.AxesImage at 0x1f47c152588>,
#  <matplotlib.text.Text at 0x1f47c175278>)

# %% [markdown]
# ## Identify Lane Lines Functions

# %%
#Function to find lane pixels from warped image
def find_lane_pixels(binary_warped):
    # Take a histogram of the bottom half of the image, floor divide
    histogram = np.sum(binary_warped[binary_warped.shape[0]//2:,:], axis=0)
    # Create an output image to draw on and visualize the result
    out_img = np.dstack((binary_warped, binary_warped, binary_warped))
    # Find the peak of the left and right halves of the histogram
    # These will be the starting point for the left and right lines
    midpoint = np.int(histogram.shape[0]//2)
    leftx_base = np.argmax(histogram[:midpoint])
    rightx_base = np.argmax(histogram[midpoint:]) + midpoint

    # HYPERPARAMETERS
    # Choose the number of sliding windows
    nwindows = 9
    # Set the width of the windows +/- margin
    margin = 100
    # Set minimum number of pixels found to recenter window
    minpix = 50

    # Set height of windows - based on nwindows above and image shape
    window_height = np.int(binary_warped.shape[0]//nwindows)
    # Identify the x and y positions of all nonzero pixels in the image
    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    # Current positions to be updated later for each window in nwindows
    leftx_current = leftx_base
    rightx_current = rightx_base

    # Create empty lists to receive left and right lane pixel indices
    left_lane_inds = []
    right_lane_inds = []

    # Step through the windows one by one
    for window in range(nwindows):
        # Identify window boundaries in x and y (and right and left)
        win_y_low = binary_warped.shape[0] - (window+1)*window_height
        win_y_high = binary_warped.shape[0] - window*window_height
        ### Find the four below boundaries of the window ###
        win_xleft_low = leftx_current - margin  # Update this
        win_xleft_high = leftx_current + margin  # Update this
        win_xright_low = rightx_current -margin  # Update this
        win_xright_high = rightx_current +margin # Update this
              
        ### Identify the nonzero pixels in x and y within the window ###
        good_left_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & 
        (nonzerox >= win_xleft_low) &  (nonzerox < win_xleft_high)).nonzero()[0]
        good_right_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & 
        (nonzerox >= win_xright_low) &  (nonzerox < win_xright_high)).nonzero()[0]
        #print(type(good_right_inds),type(good_right_inds[0]))
        # Append these indices to the lists
        left_lane_inds.append(good_left_inds)
        right_lane_inds.append(good_right_inds)
        
        ### If you found > minpix pixels, recenter next window ###
        ### (`right` or `leftx_current`) on their mean position ###
        if len(good_left_inds) > minpix:
            leftx_current = np.int(np.mean(nonzerox[good_left_inds]))
        if len(good_right_inds) > minpix:        
            rightx_current = np.int(np.mean(nonzerox[good_right_inds]))
        #print(len(left_lane_inds),np.concatenate(left_lane_inds).shape)
    # Concatenate the arrays of indices (previously was a list of lists of pixels)
    try:
        left_lane_inds = np.concatenate(left_lane_inds)
        right_lane_inds = np.concatenate(right_lane_inds)
    except ValueError:
        # Avoids an error if the above is not implemented fully
        pass

    # Extract left and right line pixel positions
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds] 
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds]

    return leftx, lefty, rightx, righty

# %%
#Function to used found lane line pixels to fit polynomial and find real curvature
def fitpoly_pixel(binary_warped):
    # Find our lane pixels first
    leftx, lefty, rightx, righty = find_lane_pixels(binary_warped)

    ### TO-DO: Fit a second order polynomial to each using `np.polyfit` ###
    left_fit = np.polyfit(lefty,leftx,2)
    right_fit = np.polyfit(righty,rightx,2)

    # Generate x and y values for plotting
    ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0] )
    try:
        left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
        right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]
    except TypeError:
        # Avoids an error if `left` and `right_fit` are still none or incorrect
        print('The function failed to fit a line!')
        left_fitx = 1*ploty**2 + 1*ploty
        right_fitx = 1*ploty**2 + 1*ploty
    return left_fit, right_fit, left_fitx, right_fitx, ploty

# %%
def real_curvature(binary_warped,left_fitx, right_fitx, ploty):
#     # Define conversions in x and y from pixels space to meters
#     ym_per_pix = 30/Ypixel # meters per pixel in y dimension
#     xm_per_pix = 3.7/Xpixel# meters per pixel in x dimension    
    ym_per_pix = 30/binary_warped.shape[0] # meters per pixel in y dimension
    xm_per_pix = 3.7/binary_warped.shape[1]# meters per pixel in x dimension
#     print(Xpixel,Ypixel)
    #print(binary_warped.shape[1]) 1280
    #Fit new polynomials to x,y in world space 
    left_fit_cr = np.polyfit(ploty*ym_per_pix, left_fitx*xm_per_pix, 2)
    right_fit_cr = np.polyfit(ploty*ym_per_pix, right_fitx*xm_per_pix, 2)
    
    ##### Implement the calculation of R_curve (radius of curvature) #####
    y_eval = np.max(ploty)*ym_per_pix
    left_curverad = (1+(2*left_fit_cr[0]*y_eval+left_fit_cr[1])**2)**1.5/(2*np.absolute(left_fit_cr[0]))  ## Implement the calculation of the left line here
    right_curverad =(1+(2*right_fit_cr[0]*y_eval+right_fit_cr[1])**2)**1.5/(2*np.absolute(right_fit_cr[0]))  ## Implement the calculation of the right line here
    
    ###Compute car offset from the center, positive right of center 
    car_offset = (0.5*binary_warped.shape[1] - (left_fitx[0] + right_fitx[0])/2) *xm_per_pix

    return left_curverad,right_curverad, car_offset

# %%
def draw_area(img,left_fitx, right_fitx, ploty,left_curverad,right_curverad, car_offset):
    undistorted = cv2.undistort(img, mtx, dist, None, mtx)
    color_warp = np.zeros_like(img)
    # Recast the x and y points into usable format for cv2.fillPoly()
#     print(left_fitx.shape,ploty.shape)
    pts_left = np.array([np.transpose(np.vstack([left_fitx, ploty]))])
    pts_right = np.array([np.flipud(np.transpose(np.vstack([right_fitx, ploty])))])
    pts = np.hstack((pts_left, pts_right))
    
    curvature = (left_curverad + right_curverad)/2

    str1 = " Radius of Curvature = %.0f" %curvature + 'm' 
    if car_offset> 0:
        str2 = " Vehicle is %.2f" %car_offset + 'm right of lane center'
    else:
        str2 = " Vehicle is %.2f" %-car_offset + 'm left of lane center'
    # Draw the lane onto the warped blank image
    cv2.fillPoly(color_warp, np.int_([pts]), (0,255, 0))

    # Warp the blank back to original image space using inverse perspective matrix (Minv)
    newwarp = cv2.warpPerspective(color_warp, Minv, (img.shape[1], img.shape[0])) 
    
    result = cv2.addWeighted(undistorted, 1, newwarp, 0.3, 0)
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(result,str1,(10,60), font, 2, (255, 255, 255), 4, cv2.LINE_AA)
    cv2.putText(result,str2,(10,130), font, 2, (255, 255, 255), 4, cv2.LINE_AA)
    
    return result

# %% [markdown]
# ## Video Frame Process

# %%
# Define a class to receive the characteristics of each line detection
class Line():
    def __init__(self):
        # was the line detected in the last iteration?
        self.detected = False  
        # x values of the last n fits of the line
        self.recent_xfitted = [] 
        #average x values of the fitted line over the last n iterations
        self.bestx = None     
        #polynomial coefficients averaged over the last n iterations
        self.best_fit = None  
        #polynomial coefficients for the most recent fit
        self.current_fit = [] # [np.array([False])]  
        #radius of curvature of the line in some units
        self.radius_of_curvature = None 
        #distance in meters of vehicle center from the line
        self.line_base_pos = None 
        #difference in fit coefficients between last and new fits
        self.diffs = np.array([0,0,0], dtype='float') 
        #x values for detected line pixels
        self.allx = None  
        #y values for detected line pixels
        self.ally = None

# %%
from pprint import pprint
Left_Lines=[]
for i in range(3): 
    left_line=Line()
    left_line.bestx=i
    Left_Lines.append(left_line)
print(len(Left_Lines))
print([o.bestx for o in Left_Lines[0:2]])
# Out:
# 3
# [0, 1]

# %%
a = np.array([1, 2,3,4])
b = np.array([5, 6,7,8])
c=np.stack((a, b), axis=0)
d= np.average(c, axis=0)
# print(type(c),a.shape,b.shape,c[1].shape,c,d)
a1=a.reshape(1,-1)
print(c.shape, a1.shape)
e= np.append(c,a1,axis=0)
f= e.reshape(-1,2)
print(f.shape)
print(np.divide(a-b,b))
# Out:
# (2, 4) (1, 4)
# (6, 2)
# [-0.8        -0.66666667 -0.57142857 -0.5       ]

# %%
#Full Pipeline for each frame with lane line area marked, curvature and center offset annotated
def process_image(img):
    color_binary, combined_binary = binary_threshold(img, mtx, dist)
    binary_warped, M , Minv= perspective_transform(combined_binary,src_pts,dst_pts)
    left_fit, right_fit, left_fitx, right_fitx, ploty = fitpoly_pixel(binary_warped)
#     print(left_fitx.shape, right_fitx.shape, ploty.shape)
    left_curverad,right_curverad, car_offset = real_curvature(binary_warped,left_fitx, right_fitx, ploty)
    result = draw_area(img,left_fitx, right_fitx, ploty,left_curverad,right_curverad, car_offset)
#     print(left_curverad,right_curverad)
    left_line=Line()
    n =3 #past number of records
    if left_fitx==[]:
        left_line.detected =False
    else:
        left_line.detected =True
#         print(type(left_fitx),type(left_fit))
#         print(left_fitx.shape,left_fit.shape)
#         print(left_fitx.shape, type(left_fitx))
        if len(Left_Lines)==0:
            left_line.recent_xfitted = left_fitx
            print(left_line.recent_xfitted[:].shape)
            left_line.bestx =  np.average(left_line.recent_xfitted)
            left_line.current_fit = left_fit
            left_line.best_fit = np.average(left_line.current_fit, axis=0)
            left_line.diffs =0
        elif len(Left_Lines) < n:
            print(len(Left_Lines),'<n')
            left_line.recent_xfitted = Left_Lines[-1].recent_xfitted
            left_line.current_fit = Left_Lines[-1].current_fit
            print(left_line.recent_xfitted.reshape(-1, left_fitx.shape[0]).shape)
            print('left_fix shape is', left_fitx.reshape(1,-1).shape)
            left_line.recent_xfitted = np.append(left_line.recent_xfitted.reshape(-1,left_fitx.shape[0]), left_fitx.reshape(1,-1), axis=0) 
            left_line.bestx = np.average(left_line.recent_xfitted)
            left_line.current_fit = np.append(left_line.current_fit.reshape(-1,left_fit.shape[0]), left_fit.reshape(1,-1), axis=0) 
            left_line.best_fit = np.average(left_line.current_fit, axis=0)
            left_line.diffs = np.array(left_line.current_fit[-1] - left_line.best_fit, dtype='float')
        else:
            print(len(Left_Lines),'>=n')
            left_line.recent_xfitted = Left_Lines[-1].recent_xfitted
            left_line.current_fit = Left_Lines[-1].current_fit
#             print(left_line.recent_xfitted[:].shape)
            print('left_fix shape is', left_fitx.reshape(1,-1).shape)
            print(left_line.recent_xfitted[-n:,:].shape)
            left_line.recent_xfitted = np.append(left_line.recent_xfitted[-n:,:], left_fitx.reshape(1,-1), axis=0) 
            left_line.bestx = np.average(left_line.recent_xfitted)
            left_line.current_fit = np.append(left_line.current_fit[-3:,:], left_fit.reshape(1,-1), axis=0) 
            left_line.best_fit = np.average(left_line.current_fit, axis=0)
            left_line.diffs = np.divide((left_line.current_fit[-1] - left_line.best_fit),left_line.current_fit[-1])
       
        left_line.radius_of_curvature = left_curverad
        left_line.line_base_pos = car_offset
        Left_Lines.append(left_line)

    print([o.detected for o in Left_Lines])
    print([o.recent_xfitted.shape for o in Left_Lines])
    print([o.bestx for o in Left_Lines])
    print([o.current_fit.shape for o in Left_Lines])
    print([o.best_fit for o in Left_Lines])
    print([o.radius_of_curvature for o in Left_Lines])
    print([o.line_base_pos for o in Left_Lines])
    print([o.diffs for o in Left_Lines])
    return result

# %%
Left_Lines=[]
Right_Lines=[]
for name in glob.glob('issue_images/project_video_30_34/OrigFrame00*'):
    img = cv2.imread(name)
    result = process_image(img)
    print(len(Left_Lines))
print(Left_Lines[-1].detected)
print(Left_Lines[-1].recent_xfitted.shape)
print(Left_Lines[-1].bestx)
print(Left_Lines[-1].current_fit.shape)
print(Left_Lines[-1].best_fit)
print(Left_Lines[-1].radius_of_curvature)
print(Left_Lines[-1].line_base_pos)
print(Left_Lines[-1].diffs)
# Out:
# (720,)
# [True]
# [(720,)]
# [431.70826010078002]
# [(3,)]
# [173.17097302742494]
# [1721.3510695261971]
# [-0.60499461007271349]
# [0]
# 1
# 1 <n
# (1, 720)
# left_fix shape is (1, 720)
# [True, True]
# [(720,), (2, 720)]
# [431.70826010078002, 433.2202120614923]
# [(3,), (2, 3)]
# [173.17097302742494, array([  1.72196433e-04,  -3.27672522e-01,   5.21324902e+02])]
# [1721.3510695261971, 1767.2959966925375]
# [-0.60499461007271349, -0.62744543129077701]
# [0, array([ -2.26738310e-06,   1.16723812e-03,   1.48331778e+00])]
# 2
# 2 <n
# (2, 720)
# left_fix shape is (1, 720)
# [True, True, True]
# [(720,), (2, 720), (3, 720)]
# [431.70826010078002, 433.2202120614923, 436.01802552818594]
# [(3,), (2, 3), (3, 3)]
# [173.17097302742494, array([  1.72196433e-04,  -3.27672522e-01,   5.21324902e+02]), array([  1.69240013e-04,  -3.26891526e-01,   5.24351753e+02])]
# [1721.3510695261971, 1767.2959966925375, 1838.7512496008478]
# [-0.60499461007271349, -0.62744543129077701, -0.65290275100332507]
# [0, array([ -2.26738310e-06,   1.16723812e-03,   1.48331778e+00]), array([ -5.91284042e-06,   1.56199260e-03,   6.05370178e+00])]
# 3
# 3 >=n
# left_fix shape is (1, 720)
# (3, 720)
# [True, True, True, True]
# [(720,), (2, 720), (3, 720), (4, 720)]
# [431.70826010078002, 433.2202120614923, 436.01802552818594, 436.98746675789442]
# [(3,), (2, 3), (3, 3), (4, 3)]
# [173.17097302742494, array([  1.72196433e-04,  -3.27672522e-01,   5.21324902e+02]), array([  1.69240013e-04,  -3.26891526e-01,   5.24351753e+02]), array([  1.62579554e-04,  -3.20940247e-01,   5.24330240e+02])]
# [1721.3510695261971, 1767.2959966925375, 1838.7512496008478, 2106.0657711930758]
# [-0.60499461007271349, -0.62744543129077701, -0.65290275100332507, -0.6523609237531347]
# [0, array([ -2.26738310e-06,   1.16723812e-03,   1.48331778e+00]), array([ -5.91284042e-06,   1.56199260e-03,   6.05370178e+00]), array([ -1.40123665e-01,  -5.89067554e-02,  -1.23102483e-04])]
# 4
# 4 >=n
# left_fix shape is (1, 720)
# (3, 720)
# [True, True, True, True, True]
# [(720,), (2, 720), (3, 720), (4, 720), (4, 720)]
# 10
# True
# (4, 720)
# 439.131893826
# (4, 3)
# [  2.40266833e-04  -3.47635472e-01   5.22675193e+02]
# 1330.67429154
# -0.621213063813
# [-0.06465544 -0.02257018 -0.00322777]

# %% [markdown]
# Plan Friday:
#     1. smooth, use search_on_poly, reset, etc with line class defined
#     2. output project.mp4 without issue, finish write up, it may help the behavior cloning project, by identifying the lane lines first, then apply to CNN?
#     3. try challenges, detect only yellow or white lane lines from hsl h

# %%
#Full Pipeline for each frame with lane line area marked, curvature and center offset annotated
def process_image(img):
    color_binary, combined_binary = binary_threshold(img, mtx, dist)
    binary_warped, M , Minv= perspective_transform(combined_binary,src_pts,dst_pts)
    left_fit, right_fit, left_fitx, right_fitx, ploty = fitpoly_pixel(binary_warped)
    left_curverad,right_curverad, car_offset = real_curvature(binary_warped,left_fitx, right_fitx, ploty)
    result = draw_area(img,left_fitx, right_fitx, ploty,left_curverad,right_curverad, car_offset)
    return result

# %%
filename = 'issue25.jpg'
img = cv2.imread('issue_images/'+ filename)
result = process_image(img)

r, g, b = cv2.split(result)
result = cv2.merge((b,g,r))
plt.figure(figsize=(16,8))
plt.imshow(result),plt.title('Warped binary with lane lines'),\
#cv2.imwrite('issue_images/output_'+filename,result)
# Out:
# (<matplotlib.image.AxesImage at 0x1f4001b6eb8>,
#  <matplotlib.text.Text at 0x1f4000945c0>)

# %%
#video processed
video_name = "test_videos/project_video.mp4"#"challenge_video.mp4" #"harder_challenge_video.mp4" #"project_video.mp4"
output_name = 'output_videos/output_30_34_project_video.mp4'
#clip of video
clip1 = VideoFileClip(video_name).subclip(30,34)
#process the images and generate the clip with lanelines
output_clip = clip1.fl_image(process_image) 
#write the ouput clip to mp4
# %time output_clip.write_videofile(output_name, audio=False)

#debug the original and processed frames from the videos
clip1.write_images_sequence('issue_images/project_video_30_34/OrigFrame%03d.jpg', fps=10, progress_bar=True)
output_clip.write_images_sequence('issue_images/project_video_30_34/ImproveFrame%03d.jpg', fps=10, progress_bar=True)
# Out:
# [MoviePy] >>>> Building video output_videos/output_30_34_project_video.mp4
# [MoviePy] Writing video output_videos/output_30_34_project_video.mp4
#  99%|███████████████████████████████████████████████████████████████████████████████▏| 100/101 [00:20<00:00,  4.96it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: output_videos/output_30_34_project_video.mp4
#
# Wall time: 21.8 s
# [MoviePy] Writing frames issue_images/project_video_30_34/OrigFrame%03d.jpg.
# 40it [00:02, 16.72it/s]
# [MoviePy]: Done writing frames issue_images/project_video_30_34/OrigFrame%03d.jpg.
#
# [MoviePy] Writing frames issue_images/project_video_30_34/ImproveFrame%03d.jpg.
# 40it [00:11,  3.38it/s]
# [MoviePy]: Done writing frames issue_images/project_video_30_34/ImproveFrame%03d.jpg.
# ['issue_images/project_video_30_34/ImproveFrame000.jpg',
#  'issue_images/project_video_30_34/ImproveFrame001.jpg',
#  'issue_images/project_video_30_34/ImproveFrame002.jpg',
#  'issue_images/project_video_30_34/ImproveFrame003.jpg',
#  'issue_images/project_video_30_34/ImproveFrame004.jpg',
#  'issue_images/project_video_30_34/ImproveFrame005.jpg',
#  'issue_images/project_video_30_34/ImproveFrame006.jpg',
#  'issue_images/project_video_30_34/ImproveFrame007.jpg',
#  'issue_images/project_video_30_34/ImproveFrame008.jpg',
#  'issue_images/project_video_30_34/ImproveFrame009.jpg',
#  'issue_images/project_video_30_34/ImproveFrame010.jpg',
#  'issue_images/project_video_30_34/ImproveFrame011.jpg',
#  'issue_images/project_video_30_34/ImproveFrame012.jpg',
#  'issue_images/project_video_30_34/ImproveFrame013.jpg',
#  'issue_images/project_video_30_34/ImproveFrame014.jpg',
#  'issue_images/project_video_30_34/ImproveFrame015.jpg',
#  'issue_images/project_video_30_34/ImproveFrame016.jpg',
#  'issue_images/project_video_30_34/ImproveFrame017.jpg',
#  'issue_images/project_video_30_34/ImproveFrame018.jpg',
#  'issue_images/project_video_30_34/ImproveFrame019.jpg',
#  'issue_images/project_video_30_34/ImproveFrame020.jpg',
#  'issue_images/project_video_30_34/ImproveFrame021.jpg',
#  'issue_images/project_video_30_34/ImproveFrame022.jpg',
#  'issue_images/project_video_30_34/ImproveFrame023.jpg',
#  'issue_images/project_video_30_34/ImproveFrame024.jpg',
#  'issue_images/project_video_30_34/ImproveFrame025.jpg',
#  'issue_images/project_video_30_34/ImproveFrame026.jpg',
#  'issue_images/project_video_30_34/ImproveFrame027.jpg',
#  'issue_images/project_video_30_34/ImproveFrame028.jpg',
#  'issue_images/project_video_30_34/ImproveFrame029.jpg',
#  'issue_images/project_video_30_34/ImproveFrame030.jpg',
#  'issue_images/project_video_30_34/ImproveFrame031.jpg',
#  'issue_images/project_video_30_34/ImproveFrame032.jpg',
#  'issue_images/project_video_30_34/ImproveFrame033.jpg',
#  'issue_images/project_video_30_34/ImproveFrame034.jpg',
#  'issue_images/project_video_30_34/ImproveFrame035.jpg',
#  'issue_images/project_video_30_34/ImproveFrame036.jpg',
#  'issue_images/project_video_30_34/ImproveFrame037.jpg',
#  'issue_images/project_video_30_34/ImproveFrame038.jpg',
#  'issue_images/project_video_30_34/ImproveFrame039.jpg']

# %%
Problem at 23 second, need slower video per FPS

# %%
#Skip the sliding windows step once you've found the lines
#function to fit polynomial
#function to search around polynomial
def search_around_poly(binary_warped):
    # HYPERPARAMETER
    # Choose the width of the margin around the previous polynomial to search
    # The quiz grader expects 100 here, but feel free to tune on your own!
    margin = 100

    # Grab activated pixels
    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    
    ### TO-DO: Set the area of search based on activated x-values ###
    ### within the +/- margin of our polynomial function ###
    ### Hint: consider the window areas for the similarly named variables ###
    ### in the previous quiz, but change the windows to our new search area ###
    left_lane_inds =((nonzerox > (left_fit[0]*(nonzeroy**2) + left_fit[1]*nonzeroy + 
                    left_fit[2] - margin)) & (nonzerox < (left_fit[0]*(nonzeroy**2) + 
                    left_fit[1]*nonzeroy + left_fit[2] + margin)))
    right_lane_inds = ((nonzerox > (right_fit[0]*(nonzeroy**2) + right_fit[1]*nonzeroy + 
                    right_fit[2] - margin)) & (nonzerox < (right_fit[0]*(nonzeroy**2) + 
                    right_fit[1]*nonzeroy + right_fit[2] + margin)))
    
    # Again, extract left and right line pixel positions
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds] 
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds]

    # Fit new polynomials
    # Generate x and y values for plotting
    ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0])
    ### Calc both polynomials using ploty, left_fit and right_fit ###
    left_fitx = left_fit[0] *ploty*ploty + left_fit[1]*ploty +left_fit[2]
    right_fitx = right_fit[0]*ploty*ploty +right_fit[1]*ploty + right_fit[2]
    
    ## Visualization ##
    # Create an image to draw on and an image to show the selection window
    out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255
    window_img = np.zeros_like(out_img)
    # Color in left and right line pixels
    out_img[nonzeroy[left_lane_inds], nonzerox[left_lane_inds]] = [255, 0, 0]
    out_img[nonzeroy[right_lane_inds], nonzerox[right_lane_inds]] = [0, 0, 255]
    
    # Generate a polygon to illustrate the search window area
    # And recast the x and y points into usable format for cv2.fillPoly()
    left_line_window1 = np.array([np.transpose(np.vstack([left_fitx-margin, ploty]))])
    left_line_window2 = np.array([np.flipud(np.transpose(np.vstack([left_fitx+margin, 
                              ploty])))])
    left_line_pts = np.hstack((left_line_window1, left_line_window2))
    right_line_window1 = np.array([np.transpose(np.vstack([right_fitx-margin, ploty]))])
    right_line_window2 = np.array([np.flipud(np.transpose(np.vstack([right_fitx+margin, 
                              ploty])))])
    right_line_pts = np.hstack((right_line_window1, right_line_window2))

    # Draw the lane onto the warped blank image
    cv2.fillPoly(window_img, np.int_([left_line_pts]), (0,255, 0))
    cv2.fillPoly(window_img, np.int_([right_line_pts]), (0,255, 0))
    result = cv2.addWeighted(out_img, 1, window_img, 0.3, 0)
    
    # Plot the polynomial lines onto the image
    plt.plot(left_fitx, ploty, color='yellow')
    plt.plot(right_fitx, ploty, color='yellow')
    ## End visualization steps ##
    
    return result

# %%
# Run image through the pipeline
# Note that in your project, you'll also want to feed in the previous fits
result = search_around_poly(binary_warped)
# View your output
plt.imshow(result)

# %%
## Compute curvature and offset of the car, then plot the region for single image
